# %% [markdown]
# ### Import Python Modules and Notebooks

# %% [markdown]
# The python notebook file `InitializationOfFunctions.ipynb` runs several other notebook files that imports python modules as well as initializing other user defined functions related to clustering algorithms.

# %%
# %run ../../PythonNotebook_InitializationOfFunctions/InitializationOfFunctions.ipynb

# %% [markdown]
# ###  Analyze the effect of "amount of overlaping"

# %% [markdown]
# Following steps are used to perform experiments:
#
#     1) Create datasets with different overlapping clusters
#     2) Visualize datasets in 2 dimension
#     3) Perform analysis
#            3.1 Optimize parameters of candidate clustering algorithms based on silhouette score as a cluster evaluation metric
#            3.2 Run the algorithms with the tuned parameters.
#            3.3 Plot and compare the results.
#            3.4 Investigate unexpected results, if any.
#     4) To compare the results, run the algorithms with true parameters and compare the results.

# %% [markdown]
# #### Create Datasets

# %%
###################################################################
# Dataset properties:
# 1. three clusters with equal number of samples in each cluster
# 2. two features that are normally distributed and uncorrelated
# 3. no overlap between clusters 
###################################################################

# create parameters of the dataset
n_clusters = 3
overlap = 1.2

dataset_para_D2_1 = {  'cluster_sample_sizes':np.array([n_point]*n_clusters),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-3, -3], [-5, 0], [-1, 0]])*overlap,
                     'cluster_stds': np.array([[1, 1]]*n_clusters),
                     'cluster_xy_scalings': np.array([[1, 1]]*n_clusters),
                     'cluster_rotation_angles': np.array([0]*n_clusters), # angles in radians
                     'cluster_seed_numbers': seed_num,
                     'cluster_overlaps': overlap
                     }

# create dataset
D2_1 = create_multiclass_bivariate_data(dataset_para_D2_1, reset_seed=True)

###################################################################
# Dataset properties:
# 1. three clusters with equal number of samples in each cluster
# 2. two features that are normally distributed and uncorrelated
# 3. slight overlap between clusters 
###################################################################
# create parameters of the dataset
n_clusters = 3
overlap = 0.95

dataset_para_D2_2 = {  'cluster_sample_sizes':np.array([n_point]*n_clusters),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-3, -3], [-5, 0], [-1, 0]])*overlap,
                     'cluster_stds': np.array([[1, 1]]*n_clusters),
                     'cluster_xy_scalings': np.array([[1, 1]]*n_clusters),
                     'cluster_rotation_angles': np.array([0]*n_clusters), # angles in radians
                     'cluster_seed_numbers': seed_num,
                     'cluster_overlaps': overlap
                     }

# create dataset
D2_2 = create_multiclass_bivariate_data(dataset_para_D2_2, reset_seed=True)


###################################################################
# Dataset properties:
# 1. three clusters with equal number of samples in each cluster
# 2. two features that are normally distributed and uncorrelated
# 3. large overlap between clusters 
###################################################################
# create parameters of the dataset
n_clusters = 3
overlap = 0.7
dataset_para_D2_3 = {  'cluster_sample_sizes':np.array([n_point]*n_clusters),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-3, -3], [-5, 0], [-1, 0]])*overlap,
                     'cluster_stds': np.array([[1, 1]]*n_clusters),
                     'cluster_xy_scalings': np.array([[1, 1]]*n_clusters),
                     'cluster_rotation_angles': np.array([0]*n_clusters), # angles in radians
                     'cluster_seed_numbers': seed_num,
                     'cluster_overlaps': overlap
                     }

# create dataset
D2_3 = create_multiclass_bivariate_data(dataset_para_D2_3, reset_seed=True)

# %% [markdown]
# #### Visualize Datasets

# %%
dataset_overlap = [   (D2_1, {'name': 'D2_1', 'n_cluster': 3}),  
                       (D2_2, {'name': 'D2_2', 'n_cluster': 3}),
                       (D2_3, {'name': 'D2_3', 'n_cluster': 3})  
                      ]
# display the datasets
plot_datasets(dataset_overlap)
# # save this figure in the folder "images" in the current working directory
# current_dir = %pwd
# image_path = "".join([current_dir, '\\fig_overlap_2d_datasets'])
# plt.savefig("".join([image_path,"\\overlap_2d_datasets.pdf"]));
# plt.show() # this step should come after saving figure

# %% [markdown]
# #### Perform Analysis

# %% [markdown]
# `Results based on parameter tuning`
#
# The parameters are tuned based on average silhouette scores. The range of the parametes are provided to cover possible values for each parameters.

# %%
t0 = time.time()
y_pred_results, metric_results = optimize_parameters_and_run_algorithms(dataset_overlap, display_results=True)
t1 = time.time()

print('----------------')
print('Total Execution Time: {:.3f} seconds'.format(np.round(t1-t0, 3)))
# Out:
# Dataset D2_1 =====
#
# Optimizing Parameters:  Kmean =====
#
# Total Parameter Settings:  4
#
#
#   algorithm       init  n_clusters  score_l2
# 0      full  k-means++           2  0.466376
# 1      full  k-means++           3  0.652116
# 2      full  k-means++           4  0.533098
# 3      full  k-means++           5  0.429841
#
# Optimizing Parameters: Agglomerative single-linkage =====
#
# Total Parameter Settings:  4
#
#
#     affinity linkage  n_clusters  score_l2
# 0  euclidean  single           2  0.271092
# 1  euclidean  single           3  0.347777
# 2  euclidean  single           4  0.142831
# 3  euclidean  single           5  0.123693
#
# Optimizing Parameters: Agglomerative complete-linkage =====
#
# Total Parameter Settings:  4
#
#
#     affinity   linkage  n_clusters  score_l2
# 0  euclidean  complete           2  0.459608
# 1  euclidean  complete           3  0.650472
# 2  euclidean  complete           4  0.528502
# 3  euclidean  complete           5  0.407646
#
# ...

# %% [markdown]
# `Get the results of dataset D2_2`
#
# For the purpose of saving figure for the report

# %%
algorithms_cluster_label = y_pred_results[1] # slight overlap dataset
algo_names = ['KM', 'DBSCAN', 'Spectral', 'GMM', 'ASL', 'ACL', 'AAL', 'AWL']


# how many algorithms
n_col = len(algo_names)
n_row = 2
fig_num = 0
fig_num2 = 0
count = 0
# create figure window
fig1 = plt.figure(figsize=(n_col*f_w, n_row*f_h))
# fig2 = plt.figure(figsize=(n_col*f_w, 1*f_h))
for i, (algo_name, algo_label) in enumerate(algorithms_cluster_label):
# #     # save results of the first four algo
#     if i<4: 
#         fig_num += 1
    
#         D2_2_result = D2_2[0], algo_label

#         plt.subplot(n_row, n_col, fig_num)
# #         ax_row1 = plt.gca()
#     #     ax_row1 = fig1.add_subplot(2, n_col, i+1)
#         plot_dataset(D2_2_result, algo_names[i])
        
#         plt.subplot(n_row, n_col, fig_num+n_col)
#         ax_row2 = plt.gca()
#     #     ax_row2 = fig2.add_subplot(2, n_col, i+9)
#         silhouette_plot_only(D2_2[0], algo_label, ax_row2)

# save results of the last four algo
# comment out following lines to save figures for agglomerative        
    if i > 3:
        
        fig_num2 += 1

        D2_2_result = D2_2[0], algo_label

        plt.subplot(n_row, n_col, fig_num2)
        plot_dataset(D2_2_result, algo_names[i])

        plt.subplot(n_row, n_col, fig_num2+n_col)
        ax_row4 = plt.gca()
        silhouette_plot_only(D2_2[0], algo_label, ax_row4)
        
plt.subplots_adjust(top=0.95, bottom=0.08, left=0.10, right=0.95, hspace=0.4,
                    wspace=0.35)
# # save this figure in the folder "images" in the current working directory
# current_dir = %pwd
# image_path = "".join([current_dir, '\\results_overlap_2d_datasets'])
# plt.savefig("".join([image_path,"\\result2_overlap_2d_dataset.pdf"]));
# plt.show() # this step should come after saving figure

# %%
algorithms_cluster_label = y_pred_results[1]
algo_names = ['KM', 'DBSCAN', 'Spectral', 'GMM', 'ASL', 'ACL', 'AAL', 'AWL']
# how many algorithms
n_col = 4
n_row = 2
fig_num_row1 = 0
fig_num_row2 = 0
count = 0
X = D2_2[0]
fig1 = plt.figure(figsize=(n_col*f_w, n_row*f_h))
plt.subplots_adjust(top=0.95, bottom=0.08, left=0.10, right=0.95, hspace=0.4,
                    wspace=0.35)
for i, (algo_name, algo_label) in enumerate(algorithms_cluster_label):
    
    # save results of four algo
    plt.subplot(n_row, n_col, i+1)
    ax_row2 = plt.gca()
    silhouette_plot_only(X, algo_label, ax_row2)
    ax_row2.set_title(algo_names[i])
# # save this figure in the folder "images" in the current working directory
# current_dir = %pwd
# image_path = "".join([current_dir, '\\results_overlap_2d_datasets'])
# plt.savefig("".join([image_path,"\\result_overlap_2d_dataset.pdf"]));
# plt.show() # this step should come after saving figure

# %% [markdown]
# `Results based on true parameters`
#
# In this experiment, true parameters are fed to the algorithms. Only parameters of DBSCAN and Spectral Clustering are tuned.

# %%
t0=time.time()
run_algorithms_with_true_parameters_and_display_results(dataset_overlap)
t1 = time.time()
print('----------------')
print('Function Execution Time: {:.3f} seconds'.format(np.round(t1-t0, 3)))
# Out:
# ...
# Dataset: D2_1
#
# Parameters =====
# {'n_clusters': 3, 'init': 'k-means++', 'algorithm': 'full'}
# Parameters =====
# eps = 0.8755, min_samples = 5, metric = euclidean
# Parameters =====
# n_components = 3, affinity = nearest_neighbors, n-neighbors = 4, assign_labels = kmeans
# Parameters =====
# {'n_components': 3, 'covariance_type': 'full', 'init_params': 'kmeans', 'n_init': 10}
# Parameters =====
# {'n_clusters': 3, 'linkage': 'single', 'affinity': 'euclidean'}
# Parameters =====
# {'n_clusters': 3, 'linkage': 'complete', 'affinity': 'euclidean'}
# Parameters =====
# {'n_clusters': 3, 'linkage': 'average', 'affinity': 'euclidean'}
# Parameters =====
# {'n_clusters': 3, 'linkage': 'ward', 'affinity': 'euclidean'}
# ...
# Dataset: D2_2
#
# Parameters =====
# {'n_clusters': 3, 'init': 'k-means++', 'algorithm': 'full'}
# Parameters =====
# eps = 1.0306, min_samples = 3, metric = euclidean
# Parameters =====
# ...

# %% [markdown]
# #### Analyze Unexpected Results

# %% [markdown]
# `Dataset D2_2: DBSCAN`

# %%
# result of dbscan based on optimized parameters
test_para_D2_2, _ = get_parameter_dbscan(D2_2)
print_parameters(test_para_D2_2)
silhouette_plot(D2_2[0], get_cluster_label_dbscan(D2_2[0], test_para_D2_2))
# Out:
# eps = 1.0306122448979593,  metric = euclidean,  min_samples = 3,

# %%
test_param = test_para_D2_2
test_param['min_samples'] = 3
test_dbscan_varying_eps(D2_2[0], (0.1,0.2), test_param)
# Out:
# eps = 0.1,  metric = euclidean,  min_samples = 3,
# -----------------------
# Total cluster = 10 	 Cluster size [273   3   3   3   3   3   3   3   3   3]
#
# eps = 0.10526315789473685,  metric = euclidean,  min_samples = 3,
# -----------------------
# Total cluster = 11 	 Cluster size [270   3   3   3   3   3   3   3   3   3   3]
#
# eps = 0.1105263157894737,  metric = euclidean,  min_samples = 3,
# -----------------------
# Total cluster = 11 	 Cluster size [270   3   3   3   3   3   3   3   3   3   3]
#
# eps = 0.11578947368421053,  metric = euclidean,  min_samples = 3,
# -----------------------
# Total cluster = 12 	 Cluster size [266   3   3   3   4   3   3   3   3   3   3   3]
#
# eps = 0.12105263157894737,  metric = euclidean,  min_samples = 3,
# -----------------------
# Total cluster = 13 	 Cluster size [263   3   3   3   3   3   4   3   3   3   3   3   3]
#
# eps = 0.12631578947368421,  metric = euclidean,  min_samples = 3,
# -----------------------
# ...

# %% [markdown]
# The effect of increasing the radius has reduced the number of clusters,i.e., forming a single big cluster.

# %%
test_param = test_para_D2_2
test_param['eps'] = 0.6
test_dbscan_varying_minPnt(D2_2[0], (2,10), test_param)
# Out:
# eps = 0.6,  metric = euclidean,  min_samples = 2,
# -----------------------
# Total cluster = 4 	 Cluster size [  8 288   2   2]
#
# eps = 0.6,  metric = euclidean,  min_samples = 3,
# -----------------------
# Total cluster = 2 	 Cluster size [ 12 288]
#
# eps = 0.6,  metric = euclidean,  min_samples = 4,
# -----------------------
# Total cluster = 2 	 Cluster size [ 12 288]
#
# eps = 0.6,  metric = euclidean,  min_samples = 5,
# -----------------------
# Total cluster = 2 	 Cluster size [ 13 287]
#
# eps = 0.6,  metric = euclidean,  min_samples = 6,
# -----------------------
# Total cluster = 2 	 Cluster size [ 15 285]
#
# eps = 0.6,  metric = euclidean,  min_samples = 7,
# -----------------------
# Total cluster = 2 	 Cluster size [ 24 276]
#
# eps = 0.6,  metric = euclidean,  min_samples = 8,
# -----------------------
# Total cluster = 2 	 Cluster size [ 32 268]
#
# eps = 0.6,  metric = euclidean,  min_samples = 9,
# -----------------------
# ...

# %% [markdown]
# The effect of increasing the number of neighbours is more number of noise points.

# %% [markdown]
#
# Dataset Properties:
#
#     1 Clusters with varying amount of overlaps,
#     2 Number of features = 2,
#     3 Features of each cluster are normally distributed and i.i.d,
#     4 Number of clusters = 3, fixed,
#     5 Equal number of samples in each cluster
#     6 Equal variance in each cluster
#     7 Globular shape of clusters
#     8 ...
#
# Observations:
#
# `Dataset D2_1: No overlap`
#     - Kmean: was able to detect non-overlaping clusters,
#     - Agglomerative single-linkage: was able to detect non-overlaping clusters,
#     - Agglomerative complete-linkage: was able to detect non-overlaping clusters,
#     - Agglomerative average-linkage: was able to detect non-overlaping clusters,
#     - Agglomerative ward-linkage: was able to detect non-overlaping clusters,
#     - DBSCAN: was able to detect non-overlaping clusters,
#     - Spectral clustering: was able to detect non-overlaping clusters,
#     - GMM: was able to detect non-overlaping clusters
#
# `Dataset D2_2: slight overlap`
#     - Kmean: was able to detect slightely overlaped clusters, but overlaping points were misclassified
#     - Agglomerative single-linkage: was unable to detect slightley overlaped clusters,
#     - Agglomerative complete-linkage: was able to detect slightely overlaped clusters, but overlaping points were misclassified
#     - Agglomerative average-linkage: was able to detect largely overlaped clusters, but overlaping points were misclassified
#     - Agglomerative ward-linkage: was able to detect slightely overlaped clusters, but overlaping points were misclassified
#     - DBSCAN: was unable to detect slightely overlaped clusters,
#     - Spectral clustering: was able to detect slightely overlaped clusters, but overlaping points were misclassified
#     - GMM: was able to detect slightely overlaped clusters, but overlaping points were misclassified with certain probabilities.
#
# `Dataset D2_3: large overlap`
#     - Kmean: was able to detect largely overlaped clusters, but overlaping points were misclassified
#     - Agglomerative single-linkage: was unable to detect largely overlaped clusters, a large cluster and one point clusters.
#     - Agglomerative complete-linkage: was able to detect largely overlaped clusters, but overlaping points were misclassified
#     - Agglomerative average-linkage: was unable to detect largely overlaped clusters, created a single large cluster and few points in other clusters
#     - Agglomerative ward-linkage: was able to detect largely overlaped clusters, but overlaping points were misclassified
#     - DBSCAN: was unable to detect largely overlaped clusters, formed a large cluster with noise points
#     - Spectral clustering: was able to detect largely overlaped clusters, but overlaping points were misclassified
#     - GMM: was able to detect largely overlaped clusters, but overlaping points were misclassified with certain probabilities.
#
#
# Conclusions:
#
#     All candidate algorithms were able to detect clusters in the dataset that have above properties and non-overlaping clusters. When clusters are very closed to each other or slightely overlaps (few boundaries points among clusters), except agglomerative single-linkage algorithm that formed unbalanced clusters (a single point in two clusters), all other considered clustering algorithms were able to detect clusters. However, the performance of these algorithms was decreased compared to earlier case (non-overlaping clusters). Particularly, the border points of clusters were misclassified by the algorithms. Likewise, further increase of overlap among clusters, the performance of the algorithms is further decreased.
