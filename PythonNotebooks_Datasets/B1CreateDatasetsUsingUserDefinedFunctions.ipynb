# %% [markdown]
# ### B.1 Create Datasets Using User Defined Functions

# %%
# ==================================================================================
# Dataset properties:
# 1. two clusters with equal number of samples in each cluster
# 2. two features that are normally distributed and uncorrelated
# 3. no overlap between clusters 
# ==================================================================================
n_clusters = 2
overlap = 1

dataset_para_D1 = {  'cluster_sample_sizes':np.array([n_point]*n_clusters),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-4, 3], [4,-5]])*overlap,
                     'cluster_stds': np.array([[1, 1], [1,1]
                                              ]),
                      'cluster_xy_scalings': np.array([(1, 1), (1, 1)]),
                      'cluster_rotation_angles': np.array([0, 0]), # angles in radians
                      'cluster_seed_numbers': seed_num,
                      'cluster_overlaps': overlap,

                     }


D1 = create_multiclass_bivariate_data(dataset_para_D1)

# ==================================================================================
# Dataset properties:
# 1. three clusters with equal number of samples in each cluster
# 2. two features that are normally distributed and uncorrelated
# 3. no overlap between clusters 
# ==================================================================================
n_clusters = 3
overlap = 1

dataset_para_D2 = {  'cluster_sample_sizes':np.array([n_point]*n_clusters),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-10, -4], [-4, -8], [0, 0]])*overlap,
                     'cluster_stds': np.array([[1, 1]]*n_clusters),
                     'cluster_xy_scalings': np.array([[1, 1]]*n_clusters),
                     'cluster_rotation_angles': np.array([0]*n_clusters), # angles in radians
                     'cluster_seed_numbers': seed_num,
                     'cluster_overlaps': overlap
                     }


D2 = create_multiclass_bivariate_data(dataset_para_D2)


# ==================================================================================
# Dataset properties:
# 1. five clusters with equal number of samples in each cluster
# 2. two features that are normally distributed and uncorrelated
# 3. no overlap between clusters 
# ==================================================================================
n_clusters = 5
overlap = 1

dataset_para_D3 = {  'cluster_sample_sizes':np.array([n_point]*n_clusters),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-10, -10], [10, 10], [5, -5], [-7, 0], [2,8]])*overlap,
                     'cluster_stds': np.array([[1, 1]]*n_clusters),
                      'cluster_xy_scalings': np.array([(1, 1)]*n_clusters),
                      'cluster_rotation_angles': np.array([0]*n_clusters), # angles in radians
                      'cluster_seed_numbers': seed_num,
                      'cluster_overlaps': overlap,

                     }


D3 = create_multiclass_bivariate_data(dataset_para_D3)

# ==================================================================================
# Dataset properties:
# 1. eight clusters with equal number of samples in each cluster
# 2. two features that are normally distributed and uncorrelated
# 3. no overlap between clusters 
# ==================================================================================
# n_cluster = 8
# cor = 1
# cov = 0
# overlap = 1
# dataset_para_D4 = {'n_clusters': 8,
#                 'n_sample': [n_point]*n_cluster,
#                 'n_feature': 2, 
#                 'cluster_mean': np.array([[-10, -10], 
#                                               [10, 10], 
#                                               [5, -5], 
#                                               [-7, 0], 
#                                               [2, 8], 
#                                               [0, -10],
#                                               [-9, 9],
#                                               [9, 0]                                              
#                                               ]
#                                             ),
#                 'cluster_cov': np.array([[[cor, cov], [cov, cor]]]*n_cluster), 
#                 'overlap': overlap,  
#                 'n_seed':seed_num
#                }


# D4 = synthetic_data(dataset_para_D4, return_dataset_properties=False)


n_clusters = 8
overlap = 1

dataset_para_D4 = {  'cluster_sample_sizes':np.array([n_point]*n_clusters),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-10, -10], 
                                              [10, 10], 
                                              [5, -5], 
                                              [-7, 0], 
                                              [2, 8], 
                                              [0, -10],
                                              [-9, 9],
                                              [9, 0]                                             
                                              ]
                                            )*overlap,
                     'cluster_stds': np.array([[1, 1]]*n_clusters),
                      'cluster_xy_scalings': np.array([(1, 1)]*n_clusters),
                      'cluster_rotation_angles': np.array([0]*n_clusters), # angles in radians
                      'cluster_seed_numbers': seed_num,
                      'cluster_overlaps': overlap,

                     }


D4 = create_multiclass_bivariate_data(dataset_para_D4)



# # ==================================================================================
# # Dataset properties:
# # 1. eleven clusters with equal number of samples in each cluster
# # 2. two features that are normally distributed and uncorrelated
# # 3. no overlap between clusters 
# # ==================================================================================

# n_cluster = 11
# cor = 1
# cov = 0
# overlap = 1
# dataset_para_D5 = {'n_clusters': 11,
#                 'n_sample': [n_point]*n_cluster,
#                 'n_feature': 2, 
#                 'cluster_mean': np.array([[-10, -10], 
#                                               [10, 10], 
#                                               [5, -5], 
#                                               [-7, 0], 
#                                               [2, 8], 
#                                               [0, -10],
#                                               [-9, 9],
#                                               [9, 0],
#                                               [-5, 5],
#                                               [0, 0],
#                                               [10, -10]
#                                             ]),
#                 'cluster_cov': np.array([[[cor, cov], [cov, cor]]]*n_cluster), 
#                 'overlap': overlap,  
#                 'n_seed':seed_num
#                }


# D5 = synthetic_data(dataset_para_D5, return_dataset_properties=False)

n_clusters = 11
overlap = 1

dataset_para_D5 = {  'cluster_sample_sizes':np.array([n_point]*n_clusters),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-10, -10],
                                                [10, 10], 
                                                [5, -5], 
                                                [-7, 0], 
                                                [2, 8], 
                                                [0, -10],
                                                [-9, 9],
                                                [9, 0],
                                                [-5, 5],
                                                [0, 0],
                                                [10, -10]
                                              ]
                                            )*overlap,
                     'cluster_stds': np.array([[1, 1]]*n_clusters),
                      'cluster_xy_scalings': np.array([(1, 1)]*n_clusters),
                      'cluster_rotation_angles': np.array([0]*n_clusters), # angles in radians
                      'cluster_seed_numbers': seed_num,
                      'cluster_overlaps': overlap,

                     }


D5 = create_multiclass_bivariate_data(dataset_para_D5)

# # ==================================================================================
# # Dataset properties:
# # 1. sixteen clusters with equal number of samples in each cluster
# # 2. two features that are normally distributed and uncorrelated
# # 3. no overlap between clusters 
# # ==================================================================================
# n_cluster = 16
# cor = 1
# cov = 0
# overlap = 1.5
# dataset_para_D6 = {'n_clusters': 16,
#                 'n_sample': [n_point]*n_cluster,
#                 'n_feature': 2, 
#                 'cluster_mean': np.array([[-10, -10], [-3.5, -10], [3.5, -10], [10, -10],
#                                               [-10, 10], [-3.3, 10], [3.5, 10], [10, 10], 
#                                               [-10, -3.5], [-3.5, -3.5], [3.5, -3.5],[10, -3.5],
#                                               [-10, 3.5], [-3.5, 3.5], [3.5, 3.5],[10, 3.5]
                                              
#                                             ]
#                                             ),
#                 'cluster_cov': np.array([[[cor, cov], [cov, cor]]]*n_cluster), 
#                 'overlap': overlap,  
#                 'n_seed':seed_num
#                }


# D6 = synthetic_data(dataset_para_D6, return_dataset_properties=False)

n_clusters = 16
overlap = 1.5

dataset_para_D6 = {  'cluster_sample_sizes':np.array([n_point]*n_clusters),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-10, -10], [-3.5, -10], [3.5, -10], [10, -10],
                                              [-10, 10], [-3.3, 10], [3.5, 10], [10, 10], 
                                              [-10, -3.5], [-3.5, -3.5], [3.5, -3.5],[10, -3.5],
                                              [-10, 3.5], [-3.5, 3.5], [3.5, 3.5],[10, 3.5]])*overlap,
                     'cluster_stds': np.array([[1, 1]]*n_clusters),
                      'cluster_xy_scalings': np.array([(1, 1)]*n_clusters),
                      'cluster_rotation_angles': np.array([0]*n_clusters), # angles in radians
                      'cluster_seed_numbers': seed_num,
                      'cluster_overlaps': overlap,

                     }


D6 = create_multiclass_bivariate_data(dataset_para_D6)


# ==================================================================================
# Dataset properties:
# 1. five clusters with equal number of samples in each cluster
# 2. two features that are normally distributed and uncorrelated
# 3. no overlap between clusters 
# ==================================================================================

# n_cluster = 5
# cor = 1
# cov = 0
# overlap= 1.3
# dataset_para_D7 = {'n_clusters': 5,
#                 'n_sample': [n_point]*n_cluster,
#                 'n_feature': 2, 
#                 'cluster_mean': np.array([[-3, -3], [3, 3], [3, -3], [-3, 3], [0, 0]]),                                             
#                 'cluster_cov': np.array([[[cor, cov], [cov, cor]]]*n_cluster), 
#                 'overlap': overlap,  
#                 'n_seed':seed_num
#                }


# D7 = synthetic_data(dataset_para_D7, return_dataset_properties=False)

n_clusters = 5
overlap = 1.3

dataset_para_D7 = {  'cluster_sample_sizes':np.array([n_point]*n_clusters),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-3, -3], [3, 3], [3, -3], [-3, 3], [0, 0]])*overlap,
                     'cluster_stds': np.array([[1, 1]]*n_clusters),
                      'cluster_xy_scalings': np.array([(1, 1)]*n_clusters),
                      'cluster_rotation_angles': np.array([0]*n_clusters), # angles in radians
                      'cluster_seed_numbers': seed_num,
                      'cluster_overlaps': overlap
                     }


D7 = create_multiclass_bivariate_data(dataset_para_D7)


# ==================================================================================
# Dataset properties:
# 1. five clusters with equal number of samples in each cluster
# 2. two features that are normally distributed and uncorrelated
# 3. overlap between clusters 
# ==================================================================================

# n_cluster = 5
# cor = 1
# cov = 0
# overlap= 0.6
# dataset_para_D8 = {'n_clusters': 5,
#                 'n_sample': [n_point]*n_cluster,
#                 'n_feature': 2, 
#                 'cluster_mean': np.array([[-3, -3], [3, 3], [3, -3], [-3, 3], [0, 0]]),                                             
#                 'cluster_cov': np.array([[[cor, cov], [cov, cor]]]*n_cluster), 
#                 'overlap': overlap,  
#                 'n_seed':seed_num
#                }


# D8 = synthetic_data(dataset_para_D8, return_dataset_properties=False)

n_clusters = 5
overlap = 0.8

dataset_para_D8 = {  'cluster_sample_sizes':np.array([n_point]*n_clusters),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-3, -3], [3, 3], [3, -3], [-3, 3], [0, 0]])*overlap,
                     'cluster_stds': np.array([[1, 1]]*n_clusters),
                      'cluster_xy_scalings': np.array([(1, 1)]*n_clusters),
                      'cluster_rotation_angles': np.array([0]*n_clusters), # angles in radians
                      'cluster_seed_numbers': seed_num,
                      'cluster_overlaps': overlap
                     }


D8 = create_multiclass_bivariate_data(dataset_para_D8)

# ==================================================================================
# Dataset properties:
# 1. three clusters with unequal number of samples in each cluster
# 2. two features that are normally distributed and uncorrelated
# 3. no overlap between clusters 
# ==================================================================================

# n_cluster = 3
# cor = 1
# cov = 0
# overlap= 1
# dataset_para_D9 = {'n_clusters': 3,
#                 'n_sample': np.array([n_point, 4*n_point, 11*n_point]),
#                 'n_feature': 2, 
#                 'cluster_mean': np.array([[-3, -3], [3, 3], [3, -3]]),
                                             
#                 'cluster_cov': np.array([[[cor, cov], [cov, cor]]]*n_cluster), 
#                 'overlap': overlap,  
#                 'n_seed':seed_num
#                }


# D9 = synthetic_data(dataset_para_D9, return_dataset_properties=False)

n_clusters = 3
overlap = 1

dataset_para_D9 = {  'cluster_sample_sizes':np.array([n_point, 4*n_point, 11*n_point]),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-3, -3], [3, 3], [3, -3]])*overlap,
                     'cluster_stds': np.array([[1, 1]]*n_clusters),
                      'cluster_xy_scalings': np.array([(1, 1)]*n_clusters),
                      'cluster_rotation_angles': np.array([0]*n_clusters), # angles in radians
                      'cluster_seed_numbers': seed_num,
                      'cluster_overlaps': overlap
                     }


D9 = create_multiclass_bivariate_data(dataset_para_D9)


# ==================================================================================
# Dataset properties:
# 1. three clusters with equal number of samples in each cluster
# 2. two features that are normally distributed and correlated
# 3. slight overlap between clusters 
# ==================================================================================

# n_cluster = 4
# cor = 0.8
# cov = 0.5
# overlap= 1
# dataset_para_D10 = {'n_clusters': 4,
#                 'n_sample': np.array([n_point]*n_cluster),
#                 'n_feature': 2, 
#                 'cluster_mean': np.array([[-3, -3], [3, 3], [3, -3], [-3, 3]]),                                             
#                 'cluster_cov': np.array([[[cor, cov], [cov, cor]],
#                                          [[cor, cov], [cov, cor]],
#                                          [[cor, -cov], [-cov, cor]],
#                                          [[cor, -cov], [-cov, cor]]
                                        
#                                         ]), 
#                 'overlap': overlap,  
#                 'n_seed':seed_num
#                }


# D10 = synthetic_data(dataset_para_D10, return_dataset_properties=False)

n_clusters = 4
overlap = 0.8

dataset_para_D10 = {  'cluster_sample_sizes':np.array([n_point]*n_clusters),
                     'cluster_nums':n_clusters,
                     'cluster_means': np.array([[-3, -3], [3, 3], [3, -3], [-3, 3]])*overlap,
                     'cluster_stds': np.array([[1, 0.3]]*n_clusters),
                      'cluster_xy_scalings': np.array([(1, 1)]*n_clusters),
                      'cluster_rotation_angles': np.array([np.pi/2, -np.pi/4, np.pi/3, -np.pi/5]), # angles in radians
                      'cluster_seed_numbers': seed_num,
                      'cluster_overlaps': overlap
                     }


D10 = create_multiclass_bivariate_data(dataset_para_D10)


# ==================================================================================
# Dataset properties:
# 1. four clusters with equal number of samples in each cluster
# 2. two features that are uniformally distributed
# 3. square shape clusters 
# ==================================================================================


D11 = create_square_cluster([n_point, n_point, n_point, n_point])
