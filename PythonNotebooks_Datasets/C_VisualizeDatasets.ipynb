# %% [markdown]
# ### Import Python Modules

# %% [markdown]
# Notebook file `import_modules.ipynb` contains commands to imports all the necessary python modules such as `numpy`, `scipy`, `pandas`, `sklearn`, `matplotlib` etc.

# %%
# Run the python notebook 'import_modules.ipynb' that is in the file directory `ImportPythonModuels`, 
# which is one level up from the current working directory  

# %run ../ImportPythonModules/import_modules.ipynb

# %% [markdown]
# #### Python Module Versions

# %%
# Display versions of python modules 
print("Sklearn vesrion:           ", sk.__version__)
print("Pandas version:            ",pd.__version__)
print("Numpy version:             ", np.__version__)
print("Scipy verson:              ", sc.__version__)
# Out:
# Sklearn vesrion:            0.21.1
# Pandas version:             0.23.4
# Numpy version:              1.16.3
# Scipy verson:               1.2.1

# %% [markdown]
# ### Import Python Notebooks

# %% [markdown]
# #### Notebooks related to datasets

# %% [markdown]
# `A1FunctionToCreateDatasets.ipynb`: contains user-defined functions to create datasets with normally distributed variables. `A11FunctionsToDisplayDatasets.ipynb`: contains user-defined functions to display the datasets.
# `B1CreateDatasetsUsingUserDefinedFunctions.ipynb`: creates datasets using user-defined functions.
# `B2CreateDatasetsUsingSklearnFunctions.ipynb`: creates datasets using functions defined in sklearn

# %%
# Run the python notebooks `A1FunctionToCreateDatasets.ipynb` and `A11FunctionsToDisplayDatasets.ipynb` 
# that are in the current working directory `PythonNotebooks_Datasets`.

# %run ./A1FunctionToCreateDatasets.ipynb
# %run ./A11FunctionsToDisplayDatasets.ipynb

# Run the python notebooks 'B1CreateDatasetsUsingUserDefinedFunctions.ipynb' and 
# 'B2CreateDatasetsUsingSklearnFunctions.ipynb' that are in the current working directory 'PythonNotebooks_Datasets'

# %run ./B1CreateDatasetsUsingUserDefinedFunctions.ipynb
# %run ./B2CreateDatasetsUsingSklearnFunctions.ipynb

# %% [markdown]
# ### C. Visualize datasets

# %%
data     = [# num_of clusters
            (D1, {'name': 'D1', 'n_cluster': 2}),                           
            (D2, {'name': 'D2', 'n_cluster': 3}),                       
            (D3, {'name': 'D3', 'n_cluster': 5}),                      
            (D4, {'name': 'D4', 'n_cluster': 8}),
            (D5, {'name': 'D5', 'n_cluster': 11}),                           
            (D6, {'name': 'D6', 'n_cluster': 16}),  
            
            (D7, {'name': 'D7', 'n_cluster': 5}), 
            (D8, {'name': 'D8', 'n_cluster': 5}),
            (D9, {'name': 'D9', 'n_cluster': 3}),   
            (D10, {'name': 'D10', 'n_cluster': 4}),                     
            (D11, {'name': 'D11', 'n_cluster': 4}),
            
            (D12, {'name': 'D12', 'n_cluster': 2}),                       
            (D13, {'name': 'D13', 'n_cluster': 2}),                      
            (D14, {'name': 'D14', 'n_cluster': 2}),
            (D15, {'name': 'D15', 'n_cluster': 2}),
                                    
            (D16, {'name': 'D16', 'n_cluster': 3}),                       
            (D17, {'name': 'D17', 'n_cluster': 4}),                      
            
            (D18, {'name': 'D18', 'n_cluster': 0}),                           
            (D19, {'name': 'D19', 'n_cluster': 3}),                       
                               
            (D20, {'name': 'D20', 'n_cluster': 3})
            
           ]

plot_datasets(data)
